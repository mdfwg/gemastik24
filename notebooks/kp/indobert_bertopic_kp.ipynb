# %% [markdown]
# # Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
from bertopic import BERTopic
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

# %% [markdown]
# # Load Data

# %%
tweet = pd.read_csv('../../src/cleaned_kp.csv')
tweet = tweet.dropna(subset=['full_text'])
tweet = tweet[['created_at', 'full_text']]
tweet['created_at'] = pd.to_datetime(tweet['created_at'])
tweet
# Out:
#                     created_at  \
# 0    2019-11-01 00:43:08+00:00
# 1    2019-11-01 02:42:52+00:00
# 2    2019-11-01 08:53:32+00:00
# 3    2019-11-01 09:15:05+00:00
# 4    2019-11-01 11:16:16+00:00
# ...                        ...
# 8431 2024-04-29 09:26:46+00:00
# 8432 2024-04-29 12:00:01+00:00
# 8433 2024-04-29 13:45:36+00:00
# 8434 2024-04-29 16:48:01+00:00
# 8435 2024-04-29 23:50:04+00:00
#
#                                               full_text
# 0                                              by lewat
# 1     kakanwil kemenag provinsi papua pdt amsal yowe...
# 2     politik baik anggota dprd betul psi libat raky...
# 3     politik baik anggota dprd betul psi libat raky...
# 4     kerja institusi  izin alami baru masuk temu bi...
# ...                                                 ...
# 8431  pintas masa depan agama indonesia lihat lebih ...
# 8432  hitung tahun ajar perintah lalu kemendikbud ja...
# 8433  bersikukuh  tinggi komersialisasi semenjak  pt...
# 8434  kagak ngotak asli dahh sbnrnya salah   sekaran...
# 8435                   bahasa inggris sd tantang imbang
#
# [8434 rows x 2 columns]

# %%
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# # Preprocess

# %%
# tweet_quarter = tweet.copy()

# tweet_quarter['quarter'] = tweet_quarter['created_at'].dt.to_period('Q')

# tweet_quarter = tweet_quarter.groupby('quarter')

# %%
tweet_time = tweet.copy()

# %%
class TextDataset(Dataset):
    def __init__(self, texts):
        self.texts = texts

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        return self.texts[idx]

# %%
text_dataset = TextDataset(tweet)

# %% [markdown]
# # Modeling

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("indobenchmark/indobert-base-p1")
model = AutoModel.from_pretrained("indobenchmark/indobert-base-p1")

# %%
from transformers import pipeline
embedding_model = pipeline("feature-extraction", model=model, tokenizer=tokenizer, device=0)
# indolem/indobert-base-uncased

# %%
results = {}

# %%
topic_model = BERTopic(verbose=False,
                        embedding_model=embedding_model, calculate_probabilities=True,
                        nr_topics=10,
                        )
text_data = tweet_time['full_text'].tolist()
timestamps = tweet_time['created_at'].tolist()

topics, probs = topic_model.fit_transform(text_data)

results = {
        'model' : topic_model,
        'topics_over_time' : topic_model.topics_over_time(text_data, timestamps, nr_bins=18),
        'probs': probs,
        'topic_info': topic_model.get_topic_info(),
        
        'topics': topics,
        'text': text_data,
    }

# %%
# %%time
# for period, group in tweet_quarter:
#     topic_model = BERTopic(verbose=False,
#                            embedding_model=embedding_model, calculate_probabilities=True,
#                            nr_topics=10,
#                            )
#     text_data = group['full_text'].tolist()
#     timestamps = group['created_at'].tolist()
#     topics, probs = topic_model.fit_transform(text_data)
#     results[period] = {
#         'model' : topic_model,
#         'topics_over_time' : topic_model.topics_over_time(text_data, timestamps, nr_bins=30),
#         'probs': probs,
#         'topic_info': topic_model.get_topic_info(),
        
#         'topics': topics,
#         'text': text_data,
#     }
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# CPU times: total: 28.4 s
# Wall time: 2min 51s

# %%
fig = results['model'].visualize_topics_over_time(results['topics_over_time'], top_n_topics=18)
# fig.update_layout(title_text=f"Topics Over Time for {period}")
fig.show()

# %%
topic_model.get_topics()
# Out:
# {-1: [('ajar', 0.029005994866241714),
#   ('menteri', 0.02463909496290714),
#   ('indonesia', 0.022507745762977108),
#   ('perintah', 0.022170892118884813),
#   ('guru', 0.02160703029739906),
#   ('jadi', 0.02124994202303235),
#   ('sekolah', 0.01967137222505872),
#   ('merdeka', 0.018508966863769894),
#   ('budaya', 0.01633341158012421),
#   ('baru', 0.016328123805663973)],
#  0: [('sekolah', 0.023824331026173005),
#   ('baik', 0.02264441104229927),
#   ('indonesia', 0.021277387834932316),
#   ('jadi', 0.020937464546624728),
#   ('buat', 0.02010130975504663),
#   ('tingkat', 0.019822356957325607),
#   ('enggak', 0.019658322187683673),
#   ('menteri', 0.01931530430842517),
#   ('ajar', 0.019014111916979423),
#   ('lebih', 0.017753256720399464)],
#  1: [('pandemi', 0.1428694886118967),
#   ('masa', 0.09722004022816408),
#   ('covid', 0.08593744082290117),
#   ('tengah', 0.05574149677021915),
#   ('perintah', 0.054103793722644206),
#   ('lama', 0.046952279655162216),
#   ('inews', 0.037819538510577164),
#   ('pesantren', 0.03580985368153277),
#   ('indonesia', 0.03485250727456335),
#   ('prinsip', 0.03416299656914862)],
#  2: [('uny', 0.19345716772182775),
#   ('pil', 0.10366658245871212),
#   ('ptn', 0.08271464955368624),
#   ('manajemen', 0.06562985944385401),
#   ('cm', 0.05914284263737453),
#   ('mau', 0.05115448407036192),
#   ('aku', 0.04947072525108025),
#   ('sama', 0.04621957407465171),
#   ('tanya', 0.04571438785172696),
#   ('yaa', 0.0429402765650442)],
#  3: [('dewantara', 0.09944593601237905),
#   ('ki', 0.09943472849261992),
#   ('belanda', 0.09547015843187084),
#   ('ora', 0.07492129858356553),
#   ('sing', 0.061999394236332855),
#   ('nasional', 0.061799299374015876),
#   ('hadjar', 0.061299244295644525),
#   ('hari', 0.0604835860242531),
#   ('hindia', 0.056528327448002805),
#   ('dadi', 0.04447677948717256)],
#  4: [('pokok', 0.35615873828886047),
#   ('empat', 0.3070243035417221),
#   ('saran', 0.28459139297006303),
#   ('mendikbud', 0.27607590618725486),
#   ('hendak', 0.27418682269134814),
#   ('pola', 0.24777733205873695),
#   ('bila', 0.24554466858676835),
#   ('dar', 0.23259934199086532),
#   ('timbang', 0.23259934199086532),
#   ('tetap', 0.212245638268438)],
#  5: [('musik', 0.48390081197265605),
#   ('tradisional', 0.22497380323392668),
#   ('literasi', 0.2087882969248301),
#   ('karya', 0.1762884800110132),
#   ('apresiasi', 0.1585213165247175),
#   ('lindung', 0.14323016911192737),
#   ('hak', 0.13630209835692722),
#   ('jumpa', 0.12516654866162208),
#   ('cipta', 0.1242027880004125),
#   ('teliti', 0.1230285376876596)],
#  6: [('nadiem', 0.9917524612263019),
#   ('kembang', 0.6745635279215287),
#   ('mendikbud', 0.658085700462925),
#   ('lima', 0.6258517171011704),
#   ('orientasi', 0.3023166362400435),
#   ('tempo', 0.2688054760772153),
#   ('indonesia', 0.20049560636442357),
#   ('barong', 0.15183880366556468),
#   ('lewat', 0.07916908101530436),
#   ('sampai', 0.07508649391409024)],
#  7: [('mahasiswa', 0.5081556115685192),
#   ('hari', 0.40538144481902727),
#   ('nasional', 0.38087337983506186),
#   ('undip', 0.3404405724689807),
#   ('rektorat', 0.33096893952775364),
#   ('hubung', 0.29820379174901385),
#   ('tuntut', 0.28872417787978083),
#   ('pihak', 0.23154438759251927),
#   ('selamat', 0.22959104722620186),
#   ('batal', 0.22560533232921162)],
#  8: [('akurat', 2.1353534986062894),
#   ('keliru', 2.065310666433862),
#   ('data', 1.4916576773875447),
#   ('analisis', 0.15551360387934646),
#   ('paham', 0.13384867998216082),
#   ('', 1e-05),
#   ('', 1e-05),
#   ('', 1e-05),
#   ('', 1e-05),
#   ('', 1e-05)]}

# %%
topic_model.get_topic_freq()
# Out:
#    Topic  Count
# 1      0   4695
# 2     -1   3114
# 0      1    374
# 5      2     91
# 3      3     48
# 8      4     36
# 9      5     28
# 6      6     20
# 7      7     16
# 4      8     12

# %%
topic_model.get_document_info(text_data)
# Out:
#                                                Document  Topic  \
# 0                                              by lewat      1
# 1     kakanwil kemenag provinsi papua pdt amsal yowe...      0
# 2     politik baik anggota dprd betul psi libat raky...     -1
# 3     politik baik anggota dprd betul psi libat raky...     -1
# 4     kerja institusi  izin alami baru masuk temu bi...     -1
# ...                                                 ...    ...
# 8429  pintas masa depan agama indonesia lihat lebih ...      0
# 8430  hitung tahun ajar perintah lalu kemendikbud ja...      0
# 8431  bersikukuh  tinggi komersialisasi semenjak  pt...     -1
# 8432  kagak ngotak asli dahh sbnrnya salah   sekaran...      0
# 8433                   bahasa inggris sd tantang imbang      1
#
#                                     Name  \
# 0            1_pandemi_masa_covid_tengah
# 1          0_sekolah_baik_indonesia_jadi
# 2     -1_ajar_menteri_indonesia_perintah
# 3     -1_ajar_menteri_indonesia_perintah
# 4     -1_ajar_menteri_indonesia_perintah
# ...                                  ...
# 8429       0_sekolah_baik_indonesia_jadi
# 8430       0_sekolah_baik_indonesia_jadi
# 8431  -1_ajar_menteri_indonesia_perintah
# 8432       0_sekolah_baik_indonesia_jadi
# 8433         1_pandemi_masa_covid_tengah
#
#                                          Representation  \
# 0     [pandemi, masa, covid, tengah, perintah, lama,...
# 1     [sekolah, baik, indonesia, jadi, buat, tingkat...
# 2     [ajar, menteri, indonesia, perintah, guru, jad...
# 3     [ajar, menteri, indonesia, perintah, guru, jad...
# 4     [ajar, menteri, indonesia, perintah, guru, jad...
# ...                                                 ...
# 8429  [sekolah, baik, indonesia, jadi, buat, tingkat...
# 8430  [sekolah, baik, indonesia, jadi, buat, tingkat...
# 8431  [ajar, menteri, indonesia, perintah, guru, jad...
# 8432  [sekolah, baik, indonesia, jadi, buat, tingkat...
# 8433  [pandemi, masa, covid, tengah, perintah, lama,...
#
#                                     Representative_Docs  \
# 0     [tinggi masa pandemi covid, ubah   lama masa p...
# 1     [info nih tuips visi bapak prabowo kuat standa...
# 2     [menteri  budaya kemendikbud umum ada sesuai  ...
# 3     [menteri  budaya kemendikbud umum ada sesuai  ...
# 4     [menteri  budaya kemendikbud umum ada sesuai  ...
# ...                                                 ...
# 8429  [info nih tuips visi bapak prabowo kuat standa...
# 8430  [info nih tuips visi bapak prabowo kuat standa...
# 8431  [menteri  budaya kemendikbud umum ada sesuai  ...
# 8432  [info nih tuips visi bapak prabowo kuat standa...
# 8433  [tinggi masa pandemi covid, ubah   lama masa p...
#
#                                             Top_n_words  Probability  \
# 0     pandemi - masa - covid - tengah - perintah - l...     0.405194
# 1     sekolah - baik - indonesia - jadi - buat - tin...     0.488641
# 2     ajar - menteri - indonesia - perintah - guru -...     0.645905
# 3     ajar - menteri - indonesia - perintah - guru -...     0.619910
# 4     ajar - menteri - indonesia - perintah - guru -...     0.214271
# ...                                                 ...          ...
# 8429  sekolah - baik - indonesia - jadi - buat - tin...     0.911461
# 8430  sekolah - baik - indonesia - jadi - buat - tin...     0.467127
# 8431  ajar - menteri - indonesia - perintah - guru -...     0.833745
# 8432  sekolah - baik - indonesia - jadi - buat - tin...     0.888564
# 8433  pandemi - masa - covid - tengah - perintah - l...     0.648541
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 8429                    False
# 8430                    False
# 8431                    False
# 8432                    False
# 8433                    False
#
# [8434 rows x 8 columns]

# %%
topic_model.get_representative_docs()
# Out:
# {-1: ['menteri  budaya kemendikbud umum ada sesuai  ajar masa pandemi covid mendikbud nadiem makarim kata laksana kurikulum kondisi khusus',
#   'menteri  budaya riset teknologi mendikbudristek nadiem anwar makarim kata kurikulum merdeka rupa bagi  merdeka ajar mampu kurang dampak hilang ajar akibat pandemi covid',
#   'dekat ajar jarak jauh menteri  budaya putus  ajar ajar ajar tahun ajar baru pandemi covid jadi ancam sistem ajar'],
#  0: ['info nih tuips visi bapak prabowo kuat standar sekolah cipta  lebih baik  baik semua lapis semakindekat semakinpakbowo visisubianto jelasarahnya',
#   'info nih bro harap bapak prabowo tingkat sistem  masuk  lebih baik  kualitas semua lapis semakindekat semakinpakbowo visisubianto jelasarahnya',
#   'tarik nih sis visi bapak prabowo kuat sistem sekolah buat  solutif  baik semua rakyat'],
#  1: ['tinggi masa pandemi covid',
#   'ubah   lama masa pandemi covid',
#   'ubah   lama masa pandemi covid'],
#  2: ['ptn bantu pilih mending pil   uny pil teknologi  unnes pil teknologi  unnes pil   uny',
#   'sch kalian mana peluang masuk snmsbm nya lebih besar pil unj manajemen  uny manajemen  pil unj manajemen  uny',
#   'ptn benar mana pil teknologi  uny pil   uny pil   uny pil teknologi  uny'],
#  3: ['ki hadjar dewantara pahlawan lahir mei tentang   hindia belanda boleh anak belanda orang kayak rasa bangku  semangat hari  ruh lawan ki hadjar dewantara kolonialisme belanda',
#   'selamat hari  nasional ki hadjar dewantara lahir keluarga kayak indonesia lama era kolonialisme belanda kenal berani tentang   perintah hindia belanda masa',
#   'jalan ki hajar dewantara bapak  nasional indonesia ki hadjar dewantara orang pahlawan nasional berani tentang   perintah hindia belanda masa'],
#  4: ['dar saran kemendikbud bila keluar  implementasi pola hidup baru  hendak timbang tiga',
#   'dar saran kemendikbud bila keluar  implementasi pola hidup baru  hendak timbang tiga',
#   'dar saran kemendikbud bila keluar  implementasi pola hidup baru  hendak timbang tiga'],
#  5: ['susun  tingkat apresiasi musik lalu  lindung hak cipta karya musik tradisional',
#   'rangka ingat hari musik tahun susun  tingkat apresiasi musik lalu  lindung hak cipta karya musik tradisional',
#   'susun  tingkat apresiasi musik lalu  lindung hak cipta karya musik tradisional'],
#  6: ['mendikbud nadiem kembang',
#   'mendikbud nadiem kembang',
#   'mendikbud nadiem kembang'],
#  7: ['selamat hari  nasional hubung hari  nasional  rektorat pihak ada mahasiswa mahasiswa undip tuntut batal naik ukt mahasiswa',
#   'selamat hari  nasional hubung hari  nasional  rektorat pihak ada mahasiswa mahasiswa undip tuntut batal naik ukt mahasiswa',
#   'selamat hari  nasional hubung hari  nasional  rektorat pihak ada mahasiswa mahasiswa undip tuntut batal naik ukt mahasiswa'],
#  8: ['data akurat   keliru', 'data akurat   keliru', 'data akurat   keliru']}

# %%
topic_model.generate_topic_labels()
# Out:
# ['-1_ajar_menteri_indonesia',
#  '0_sekolah_baik_indonesia',
#  '1_pandemi_masa_covid',
#  '2_uny_pil_ptn',
#  '3_dewantara_ki_belanda',
#  '4_pokok_empat_saran',
#  '5_musik_tradisional_literasi',
#  '6_nadiem_kembang_mendikbud',
#  '7_mahasiswa_hari_nasional',
#  '8_akurat_keliru_data']

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_documents(text_data)

# %%
topic_model.visualize_hierarchy()

# %%
hierarchical_topics = topic_model.hierarchical_topics(text_data)
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 72.81it/s]

# %%
# for period, result in results.items():
#     fig = result['model'].visualize_topics_over_time(result['topics_over_time'], top_n_topics=10)
#     fig.update_layout(title_text=f"Topics Over Time for {period}")
#     fig.show()

# %%
# top_topics = []


# for period, result in results.items():
#     top_10_topics = result['topic_info'][0:11]
#     # top_10_topics['Name'] = top_10_topics['Name'].str.replace(r'^\d+_', '', regex=True)
#     topic_descriptions = top_10_topics['Name'].tolist()
#     top_topics.append({'period': period, 'topics': topic_descriptions})


# top_topics_df = pd.DataFrame(top_topics)
# display(top_topics_df)

# %%
# for quarter in top_topics:
#     print(f"{quarter['period']}: {quarter['topics']}")

# %% [markdown]
# # Evaluation

# %%
# coherence_obj = {}

# for period, result in results.items():
#     documents = pd.DataFrame({"Document": result['text'],
#                               "ID": range(len(result['text'])),
#                               "Topic": result['topics'],
#                               })

#     documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
#     cleaned_docs = result['model']._preprocess_text(documents_per_topic.Document.values)

#     vectorizer = result['model'].vectorizer_model
#     analyzer = vectorizer.build_analyzer()

#     words = vectorizer.get_feature_names_out()
#     tokens = [analyzer(doc) for doc in cleaned_docs]
#     dictionary = corpora.Dictionary(tokens)
#     corpus = [dictionary.doc2bow(token) for token in tokens]
#     topic_words = [[words for words, _ in result['model'].get_topic(topic)] for topic in range(len(set(result['topics']))-1)]

#     coherence_model_c_v = CoherenceModel(topics=topic_words,
#                                     texts=tokens,
#                                     corpus=corpus,
#                                     dictionary=dictionary,
#                                     coherence='c_v')
#     coherence_model_u_mass = CoherenceModel(topics=topic_words,
#                                     texts=tokens,
#                                     corpus=corpus,
#                                     dictionary=dictionary,
#                                     coherence='u_mass')
#     coherence_c_v = coherence_model_c_v.get_coherence()
#     coherence_u_mass = coherence_model_u_mass.get_coherence()
#     coherence_obj[period] = {
#         'coherence_c_v': coherence_c_v,
#         'coherence_u_mass': coherence_u_mass,
#     }

# %%
# coherence_obj

# %%
from octis.evaluation_metrics.diversity_metrics import TopicDiversity
from octis.evaluation_metrics.coherence_metrics import Coherence
